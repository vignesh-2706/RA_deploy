# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishwas-K-S/Detection-of-RA-Using-CNN/blob/main/TrainingModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install unrar
#!unrar x "/content/Source images.rar" #//unrar images folder

# %%
# import required libraries
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
# accessing image folder for training and testing
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Source images",
    shuffle = True, 
    image_size = (256, 256), 
    batch_size = 8
)
# Out:
# Found 87 files belonging to 2 classes.

# %%
class_names = dataset.class_names

# %%
class_names
# Out:
# ['negative', 'positive']

# %%
# vizualizing the random images
plt.figure(figsize=(20,10))
for image_batch, lable_batch in dataset.take(1):
    for i in range(8):
        ax = plt.subplot(2,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[lable_batch[i]])
        plt.axis("off")

# %%
# function to split dataset into training set, testing set and validation set
def split_dataset(ds, train_split = 0.8, test_split = 0.1, val_split = 0.1, Shuffle = True, shuffle_size = 1000):
    ds_len = len(ds)
    if Shuffle:
        ds = ds.shuffle(shuffle_size, seed = 10)
    
    train_size = int(ds_len*train_split)
    val_size = int(ds_len*val_split)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, test_ds, val_ds

# %%
# calling the split_dataset function to split the dataset
train_ds, test_ds, val_ds = split_dataset(dataset)

# %%
#creating resizeing and rescaleing layer
resize_rescale = tf.keras.Sequential([
                                      layers.Resizing(256, 256),
                                      layers.Rescaling(1.0/255)

])

# %%
# creating data augmentation layer
data_augmentation = tf.keras.Sequential([
                                         layers.RandomFlip("horizontal_and_vertical"),
                                         layers.RandomRotation(0.2)
])

# %%
# creating the CNN model
input_shape = (8, 256,256, 3)

model = models.Sequential([
                           resize_rescale,
                           data_augmentation,
                           layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
                           layers.MaxPool2D(),
                           layers.Conv2D(64, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                           layers.Conv2D(64, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                           layers.Conv2D(64, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                           layers.Conv2D(32, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                           layers.Flatten(),
                           layers.Dense(32, activation='relu'),
                           layers.Dense(2, activation='softmax'),
])
model.build(input_shape=input_shape)

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (8, 256, 256, 3)          0
#
#  sequential_1 (Sequential)   (8, 256, 256, 3)          0
#
#  conv2d (Conv2D)             (8, 254, 254, 32)         896
#
#  max_pooling2d (MaxPooling2D  (8, 127, 127, 32)        0
#  )
#
#  conv2d_1 (Conv2D)           (8, 125, 125, 64)         18496
#
#  max_pooling2d_1 (MaxPooling  (8, 62, 62, 64)          0
#  2D)
#
#  conv2d_2 (Conv2D)           (8, 60, 60, 64)           36928
#
#  max_pooling2d_2 (MaxPooling  (8, 30, 30, 64)          0
#  2D)
#
#  conv2d_3 (Conv2D)           (8, 28, 28, 64)           36928
#
#  max_pooling2d_3 (MaxPooling  (8, 14, 14, 64)          0
#  2D)
#
#  conv2d_4 (Conv2D)           (8, 12, 12, 32)           18464
#
#  max_pooling2d_4 (MaxPooling  (8, 6, 6, 32)            0
#  2D)
#
#  flatten (Flatten)           (8, 1152)                 0
#
#  dense (Dense)               (8, 32)                   36896
#
#  dense_1 (Dense)             (8, 2)                    66
#
# =================================================================
# Total params: 148,674
# Trainable params: 148,674
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling model
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics = ['accuracy']
)

# %%
# fitting the model
history = model.fit(
    train_ds,
    epochs=25,
    batch_size = 8,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/25
# 8/8 [==============================] - 13s 579ms/step - loss: 0.6857 - accuracy: 0.5238 - val_loss: 0.7639 - val_accuracy: 0.1250
# Epoch 2/25
# 8/8 [==============================] - 4s 443ms/step - loss: 0.6699 - accuracy: 0.6032 - val_loss: 0.6414 - val_accuracy: 0.5000
# Epoch 3/25
# 8/8 [==============================] - 4s 408ms/step - loss: 0.6751 - accuracy: 0.5079 - val_loss: 0.6407 - val_accuracy: 0.7500
# Epoch 4/25
# 8/8 [==============================] - 4s 398ms/step - loss: 0.6639 - accuracy: 0.6667 - val_loss: 0.6683 - val_accuracy: 0.7500
# Epoch 5/25
# 8/8 [==============================] - 4s 434ms/step - loss: 0.6137 - accuracy: 0.7460 - val_loss: 0.6787 - val_accuracy: 0.5000
# Epoch 6/25
# 8/8 [==============================] - 4s 424ms/step - loss: 0.5741 - accuracy: 0.7031 - val_loss: 0.6167 - val_accuracy: 0.6250
# Epoch 7/25
# 8/8 [==============================] - 4s 438ms/step - loss: 0.5204 - accuracy: 0.7460 - val_loss: 0.4652 - val_accuracy: 0.7500
# Epoch 8/25
# 8/8 [==============================] - 4s 415ms/step - loss: 0.4695 - accuracy: 0.7344 - val_loss: 0.3863 - val_accuracy: 0.7500
# Epoch 9/25
# 8/8 [==============================] - 4s 435ms/step - loss: 0.4096 - accuracy: 0.8254 - val_loss: 0.5452 - val_accuracy: 0.7500
# Epoch 10/25
# 8/8 [==============================] - 4s 399ms/step - loss: 0.3592 - accuracy: 0.8413 - val_loss: 0.4193 - val_accuracy: 0.8750
# Epoch 11/25
# 8/8 [==============================] - 4s 420ms/step - loss: 0.3320 - accuracy: 0.8095 - val_loss: 0.2350 - val_accuracy: 0.8750
# Epoch 12/25
# 8/8 [==============================] - 4s 423ms/step - loss: 0.3481 - accuracy: 0.8413 - val_loss: 0.2535 - val_accuracy: 1.0000
# Epoch 13/25
# 8/8 [==============================] - 4s 409ms/step - loss: 0.4148 - accuracy: 0.8413 - val_loss: 0.1430 - val_accuracy: 1.0000
# Epoch 14/25
# 8/8 [==============================] - 4s 448ms/step - loss: 0.4406 - accuracy: 0.7937 - val_loss: 0.3592 - val_accuracy: 0.8750
# Epoch 15/25
# 8/8 [==============================] - 4s 432ms/step - loss: 0.3660 - accuracy: 0.8254 - val_loss: 0.3604 - val_accuracy: 0.8571
# Epoch 16/25
# 8/8 [==============================] - 4s 407ms/step - loss: 0.3327 - accuracy: 0.8413 - val_loss: 0.1872 - val_accuracy: 0.8750
# Epoch 17/25
# 8/8 [==============================] - 4s 438ms/step - loss: 0.2194 - accuracy: 0.9062 - val_loss: 0.1480 - val_accuracy: 1.0000
# Epoch 18/25
# 8/8 [==============================] - 4s 411ms/step - loss: 0.2619 - accuracy: 0.8889 - val_loss: 0.5886 - val_accuracy: 0.7500
# Epoch 19/25
# 8/8 [==============================] - 4s 402ms/step - loss: 0.3443 - accuracy: 0.8281 - val_loss: 0.1480 - val_accuracy: 0.8750
# Epoch 20/25
# 8/8 [==============================] - 4s 412ms/step - loss: 0.3497 - accuracy: 0.8571 - val_loss: 0.2233 - val_accuracy: 0.8750
# Epoch 21/25
# 8/8 [==============================] - 4s 405ms/step - loss: 0.2076 - accuracy: 0.9365 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 22/25
# 8/8 [==============================] - 4s 437ms/step - loss: 0.3548 - accuracy: 0.9048 - val_loss: 0.0659 - val_accuracy: 1.0000
# Epoch 23/25
# 8/8 [==============================] - 4s 401ms/step - loss: 0.3516 - accuracy: 0.8906 - val_loss: 0.8525 - val_accuracy: 0.6250
# Epoch 24/25
# 8/8 [==============================] - 4s 442ms/step - loss: 0.3672 - accuracy: 0.8438 - val_loss: 0.2996 - val_accuracy: 1.0000
# Epoch 25/25
# 8/8 [==============================] - 4s 435ms/step - loss: 0.2354 - accuracy: 0.9206 - val_loss: 0.3160 - val_accuracy: 0.8750

# %%
# Testing the created model aganist the test dataset
model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 1s 87ms/step - loss: 0.0638 - accuracy: 1.0000
# [0.06378519535064697, 1.0]

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# plotting the training accuracy and validation accuracy
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.plot(range(25), accuracy, label='Training Accuracy')
plt.plot(range(25), val_accuracy, label='Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
# model.save("Saved_model_v1.h5")
